# %%
import pandas as pd
import pickle

# %%
pwd
# Out:
# '/home/hainh/coccoc/code/week11/SR-GNN_PyTorch-Geometric/src'

# %%
path = '/home/hainh/coccoc/code/week11/SR-GNN_PyTorch-Geometric/datasets/diginetica/raw/'

# %%
data = pickle.load(open(path+ 'train.txt', 'rb'))

# %%
data
# Out:
# ([[1],
#   [3, 4],
#   [3],
#   [6],
#   [8],
#   [10, 11, 12, 12, 13, 14],
#   [10, 11, 12, 12, 13],
#   [10, 11, 12, 12],
#   [10, 11, 12],
#   [10, 11],
#   [10],
#   [16, 17, 18],
#   [16, 17],
#   [16],
#   [19, 19],
#   [19],
#   [21],
#   [8],
#   [23, 24, 25, 26, 27, 24],
#   [23, 24, 25, 26, 27],
#   [23, 24, 25, 26],
#   [23, 24, 25],
#   [23, 24],
#   [23],
#   [29, 30],
#   [29],
#   [32, 5, 4, 33, 34, 35],
#   [32, 5, 4, 33, 34],
#   [32, 5, 4, 33],
#   [32, 5, 4],
#   [32, 5],
#   [32],
#   [37, 38],
#   [37],
#   [40],
#   [42],
#   [44],
#   [46, 47],
#   [46],
#   [48, 49],
#   [48],
#   [51],
#   [53, 54, 53, 55, 56, 22],
#   [53, 54, 53, 55, 56],
#   [53, 54, 53, 55],
#   [53, 54, 53],
#   [53, 54],
#   [53],
#   [57, 58],
#   [57],
#   [60, 61, 61, 62, 63, 62, 64, 65, 62, 66, 67, 68],
#   [60, 61, 61, 62, 63, 62, 64, 65, 62, 66, 67],
#   [60, 61, 61, 62, 63, 62, 64, 65, 62, 66],
#   [60, 61, 61, 62, 63, 62, 64, 65, 62],
#   [60, 61, 61, 62, 63, 62, 64, 65],
# ...

# %%
# Out:
# [33128,
#  6409,
#  37169,
#  37331,
#  37334,
#  37331,
#  37243,
#  18058,
#  26382,
#  15767,
#  15767,
#  37323,
#  37467,
#  11331,
#  11331,
#  37169,
#  37146,
#  37149,
#  1166,
#  37337,
#  37337,
#  37369,
#  18084,
#  136,
#  37149,
#  37404,
#  37336,
#  37333,
#  9401,
#  37340,
#  9678,
#  37385,
#  37209,
#  1259,
#  8159,
#  37440,
#  3079,
#  37230,
#  37422,
#  37330,
#  37265,
#  37244,
#  9778,
#  37476,
#  37365,
#  37365,
#  37339,
#  37339,
#  4118,
#  37468,
#  37347,
#  37475,
#  37445,
#  37424,
#  37151,
#  37404,
#  37401,
#  37323,
#  37325,
#  37426,
#  6409,
#  37146,
#  3545,
#  37184,
#  12626,
#  5686,
#  5686,
#  11567,
#  37386,
#  37342,
#  37340,
#  32167,
#  37383,
#  37366,
#  37333,
#  37333,
#  37386,
#  37421,
#  34711,
#  36479,
#  35914,
#  35914,
#  35914,
#  35914,
#  35870,
#  34271,
#  37246,
#  37184,
#  12626,
#  37233,
#  34683,
#  34771,
#  9878,
#  3644,
#  37209,
#  37169,
#  24874,
#  1170,
#  35942,
#  34148,
#  35596,
# ...
